# %%
[203,'Hyderabad',False,True,175]

# %%
s={40,50,60,70,77,80}

# %%
s
# Out:
# {40, 50, 60, 70, 77, 80}

# %%
h={90,80,70,60,77}
h
# Out:
# {60, 70, 77, 80, 90}

# %%
type(h)
# Out:
# set

# %%
s={80,90,77,70,50}
s
# Out:
# {50, 70, 77, 80, 90}

# %%
type(s)
# Out:
# set

# %%
s.difference(h)
# Out:
# {50}

# %%
s.intersection(s)
# Out:
# {50, 70, 77, 80, 90}

# %%
s.union(h)
# Out:
# {50, 60, 70, 77, 80, 90}

# %%
s.difference(h)
# Out:
# {50}

# %%
s.symmetric_difference(h)
# Out:
# {50, 60}

# %%
a={10,20,30,40,50,60}
a
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
d=tuple(a)
d
# Out:
# (50, 20, 40, 10, 60, 30)

# %%
d={'a': 4, 'b': 7, 'c': 2}

# %%
type(d)
# Out:
# dict

# %%
d
# Out:
# {'a': 4, 'b': 7, 'c': 2}

# %%
l=[4,7,2]
l
# Out:
# [4, 7, 2]

# %%
d.get(4)

# %%
d
# Out:
# {'a': 4, 'b': 7, 'c': 2}

# %%
d={ 101: 4,102: 7,103:2}
d
# Out:
# {101: 4, 102: 7, 103: 2}

# %%
d[101]=9

# %%
d.get(102)
# Out:
# 7

# %%
d.update({101 :4})

# %%
d
# Out:
# {101: 4, 102: 7, 103: 2}

# %%
del d[101]

# %%
d
# Out:
# {102: 7, 103: 2}

# %%
d={101:5000, 103: 2, 104: 5000, 105: 50}
d
# Out:
# {101: 5000, 103: 2, 104: 5000, 105: 50}

# %%
d[101]
# Out:
# 5000

# %%
d
# Out:
# {101: 5000,
#  103: 2,
#  104: 5000,
#  105: 50,
#  102: {50: [7, 8, 9, 10], 'apple': (20, 10, 70, [90, 180, 270])}}

# %%
d[105]={'a':{30,50,70},'b':(1000,5000,7000,9000),'c':['K',{'L':[11,22],'M':(77,88)},'N']}

# %%
d[104]
# Out:
# {50: [7, 8, 9, 10], 'apple': (20, 10, 70, [90, 180, 270])}

# %%
s=(5,6,7,3,4)
s
# Out:
# (5, 6, 7, 3, 4)

# %%
d=[]
for i in s:
    d.append(i+7)

# %%
import pandas as pd
import seaborn as sns

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as ps
import warnings 
warnings.filterwarnings('ignore')

# %%
iris_data=sns.load_dataset('iris')
df=sns.load_dataset('taxis')

# %%
sns.scatterplot(x=iris_data['sepal_length'],y=iris_data['petal_length'])
plt.show()

# %%
sns.scatterplot(x=iris_data['sepal_length'],y=iris_data['petal_length'],hue=iris_data['species'],palette=['r','g','y'])
plt.show()

# %%
sns.stripplot(x=iris_data['species'],y=iris_data['sepal_width'],palette=['r','g','y'])
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
sns.stripplot(x=df['payment'],y=df['tip'],palette=['r','g'])
# Out:
# <Axes: xlabel='payment', ylabel='tip'>

# %%
sns.stripplot(x=df['payment'],y=df['total'],palette=['r','g'])
# Out:
# <Axes: xlabel='payment', ylabel='total'>

# %%
sns.lineplot(x=df['tip'],y=df['fare'],)
plt.show()

# %%
df=sns.load_dataset('taxis')

# %%
sns.lineplot(x=df['total'],y=df['fare'],)
plt.show()

# %%
sns.lineplot(x=df['total'],y=df['fare'],hue=df['payment'],palette=['red','orange'])
plt.show()

# %%
sns.lineplot(x=df['total'],y=df['fare'],hue=df['payment'],palette=['red','green'])
plt.show()

# %%
df[['payment','color']].value_counts()
# Out:
# payment      color
# credit card  yellow    4000
# cash         yellow    1412
# credit card  green      577
# cash         green      400
# Name: count, dtype: int64

# %%
df['color'].value_counts()
# Out:
# color
# yellow    5451
# green      982
# Name: count, dtype: int64

# %%
df['payment'].value_counts()
# Out:
# payment
# credit card    4577
# cash           1812
# Name: count, dtype: int64

# %% [raw]
# sns.countplot(x=df['payment'])

# %%
sns.countplot(x=df['payment'],hue=df['color'],palette=['lightgreen','skyblue'])
plt.show()

# %% [raw]
# plt.figure(figsize=(2,2))
# sns.countplot(x=df['payment'],hue=df['color'],palette=['lightgreen','skyblue'])
# plt.xlabel('Payment Mode',font_size=10)
# plt.show()

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['payment'],hue=df['color'],palette=['lightgreen','skyblue'])
plt.xlabel('Payment Mode',font_size=10)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[98], line 3
#       1 plt.figure(figsize=(2,2))
#       2 sns.countplot(x=df['payment'],hue=df['color'],palette=['lightgreen','skyblue'])
# ----> 3 plt.xlabel('Payment Mode',font_size=10)
#       4 plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:4359, in xlabel(xlabel, fontdict, labelpad, loc, **kwargs)
#    4350 @_copy_docstring_and_deprecators(Axes.set_xlabel)
#    4351 def xlabel(
#    4352     xlabel: str,
#    (...)
#    4357     **kwargs,
#    4358 ) -> Text:
# -> 4359     return gca().set_xlabel(
#    4360         xlabel, fontdict=fontdict, labelpad=labelpad, loc=loc, **kwargs
#    4361     )
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:3556, in _AxesBase.set_xlabel(self, xlabel, fontdict, labelpad, loc, **kwargs)
#    3549     x = {
#    3550         'left': 0,
# ...
